# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import numpy as np

# %% [markdown]
# ## 2) Convert datestamp column to a datetime object and set the datestamp columns as the index of your dataframe.

# %%
df = pd.read_csv("employment.csv", parse_dates=True, index_col='datestamp')
df=df.rename(columns={"Agriculture": "Agr", "Business services":"Bus Serv", "Wholesale and Retail Trade":"Who & Ret Trade",
                   "Durable goods manufacturing":"DGM", "Education and Health":"Edu and Heal", 
                      "Leisure and hospitality":"LAH","Mining and Extraction":"MAH","Transportation and Utilities":"TAU",
                      "Nondurable goods manufacturing":"NGM"})
df
# Out:
#              Agr  Bus Serv  Construction   DGM  Edu and Heal  Finance  \
# datestamp
# 2000-01-01  10.3       5.7           9.7   3.2           2.3      2.7
# 2000-02-01  11.5       5.2          10.6   2.9           2.2      2.8
# 2000-03-01  10.4       5.4           8.7   2.8           2.5      2.6
# 2000-04-01   8.9       4.5           5.8   3.4           2.1      2.3
# 2000-05-01   5.1       4.7           5.0   3.4           2.7      2.2
# ...          ...       ...           ...   ...           ...      ...
# 2009-10-01  11.8      10.3          18.7  12.9           6.0      7.0
# 2009-11-01  12.6      10.6          19.4  12.7           5.5      6.7
# 2009-12-01  19.7      10.3          22.7  13.3           5.6      7.2
# 2010-01-01  21.3      11.1          24.7  14.1           5.5      6.6
# 2010-02-01  18.8      12.0          27.1  13.6           5.6      7.5
#
#             Government  Information   LAH  Manufacturing   MAH   NGM  Other  \
# datestamp
# ...

# %% [markdown]
# ## Check if there are missing values in each column.

# %%
df.describe()
# Out:
#               Agr    Bus Serv  Construction         DGM  Edu and Heal  \
# count  122.000000  122.000000    122.000000  122.000000    122.000000
# mean     9.840984    6.919672      9.426230    6.025410      3.420492
# std      3.962067    1.862534      4.587619    2.854475      0.877538
# min      2.400000    4.100000      4.400000    2.800000      1.800000
# 25%      6.900000    5.600000      6.100000    4.125000      2.900000
# 50%      9.600000    6.450000      8.100000    5.100000      3.200000
# 75%     11.950000    7.875000     10.975000    6.775000      3.700000
# max     21.300000   12.000000     27.100000   14.100000      6.100000
#
#           Finance  Government  Information         LAH  Manufacturing  \
# count  122.000000  122.000000   122.000000  122.000000     122.000000
# mean     3.540164    2.581148     5.486885    8.315574       5.982787
# std      1.235405    0.686750     2.016582    1.605570       2.484221
# ...

# %% [markdown]
# Looking at format and the minimum values from the description, we can infer that there are no missing values.

# %% [markdown]
# ## 3)Generate a boxplot to find the distribution of unemployment rate for every industry.

# %%
plt.subplots(figsize=(20,5))
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4)Using line chart Visualize the unemployment rate of workers by industry.

# %%
df.plot(subplots=True,figsize=(12,25),ylim=(0,30), sort_columns=True)
# Out:
# array([<AxesSubplot:xlabel='datestamp'>, <AxesSubplot:xlabel='datestamp'>,
#        <AxesSubplot:xlabel='datestamp'>, <AxesSubplot:xlabel='datestamp'>,
#        <AxesSubplot:xlabel='datestamp'>, <AxesSubplot:xlabel='datestamp'>,
#        <AxesSubplot:xlabel='datestamp'>, <AxesSubplot:xlabel='datestamp'>,
#        <AxesSubplot:xlabel='datestamp'>, <AxesSubplot:xlabel='datestamp'>,
#        <AxesSubplot:xlabel='datestamp'>, <AxesSubplot:xlabel='datestamp'>,
#        <AxesSubplot:xlabel='datestamp'>, <AxesSubplot:xlabel='datestamp'>,
#        <AxesSubplot:xlabel='datestamp'>, <AxesSubplot:xlabel='datestamp'>],
#       dtype=object)

# %% [markdown]
# ## 5) Plot the monthly and yearly trends.

# %%
my_list=df.columns.values.tolist()
for str in my_list:
    fig = df[str].resample("Y").mean().plot()
    big = df[str].resample("M").mean().plot()
    plt.title(str)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-110-abc2bf47b0df> in <module>
#       1 my_list=df.columns.values.tolist()
#       2 for str in my_list:
# ----> 3     fig = df[str].resample("Y").mean().plot()
#       4     big = df[str].resample("M").mean().plot()
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in g(self, _method, *args, **kwargs)
#     966     def g(self, _method=method, *args, **kwargs):
#     967         nv.validate_resampler_func(_method, args, kwargs)
# --> 968         return self._downsample(_method)
#     969
#     970     g.__doc__ = getattr(GroupBy, method).__doc__
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _downsample(self, how, **kwargs)
#    1078         # we are downsampling
#    1079         # we want to call the actual grouper method here
# ...

# %% [markdown]
# ## 6) Apply time series decomposition to your dataset to visualize the trend and seasonality.

# %%
for str in my_list:
    decomposition = sm.tsa.seasonal_decompose(df_month[str], model='Additive').seasonal
    decomp = sm.tsa.seasonal_decompose(df_month[str], model='Additive').trend
    #decom = sm.tsa.seasonal_decompose(df_fort[my_list[i]], model='Additive').seasonal
    fig = decomposition.plot()
    big = decomp.plot()
    #wig = decom.plot()
    plt.title(str)
    plt.show()

# %% [markdown]
# ## 7) Visualize the seasonality of Agriculture, Health and Finance sector.

# %%
from pylab import rcParams
import statsmodels.api as sm
df_month = df.resample("M").mean()
df_year = df.resample("Y").mean()
rcParams['figure.figsize'] = 12, 3
decomposition = sm.tsa.seasonal_decompose(df_month['Agr'], model='Additive').seasonal
#The seasonal_decompose() method can take up to six parameters. 
fig = decomposition.plot()
plt.title("Agriculture")
plt.show()

decomposition = sm.tsa.seasonal_decompose(df_month['Edu and Heal'], model='Additive').seasonal
#The seasonal_decompose() method can take up to six parameters. 
fig = decomposition.plot()
plt.title("Education and Health")
plt.show()

decomposition = sm.tsa.seasonal_decompose(df_month['Finance'], model='Additive').seasonal
#The seasonal_decompose() method can take up to six parameters. 
fig = decomposition.plot()
plt.title("Finance")
plt.show()

# %% [markdown]
# ## 8)Visualize the seasonality of multiple time series and the correlation between each time series in the dataset.

# %% [markdown]
# Seasonality on the basis of month and quarterly

# %%
df_month = df.resample("M").mean()
df_quar = df.resample("Q").mean()


for str in my_list:
    decomposition = sm.tsa.seasonal_decompose(df_month[str], model='Additive').seasonal
    decomp = sm.tsa.seasonal_decompose(df_quar[str], model='Additive').seasonal
    #decom = sm.tsa.seasonal_decompose(df_fort[my_list[i]], model='Additive').seasonal
    fig = decomposition.plot()
    big = decomp.plot()
    #wig = decom.plot()
    plt.title(str)
    plt.show()

# %% [markdown]
# Correlation between monthy and quarterly values

# %%
corrlist= list()
for str in my_list:
    corrlist.append(df_month[str].corr(df_quar[str]))

data = {'Industry':my_list,'Correlation(month and quarter)':corrlist}

dg=pd.DataFrame(data)
dg
# Out:
#            Industry  Correlation(month and quarter)
# 0               Agr                        0.910681
# 1          Bus Serv                        0.985983
# 2      Construction                        0.965552
# 3               DGM                        0.992962
# 4      Edu and Heal                        0.936309
# 5           Finance                        0.980571
# 6        Government                        0.701258
# 7       Information                        0.972705
# 8               LAH                        0.962135
# 9     Manufacturing                        0.993166
# 10              MAH                        0.929064
# 11              NGM                        0.971379
# 12            Other                        0.932799
# 13    Self-employed                        0.972912
# 14              TAU                        0.985663
# 15  Who & Ret Trade                        0.978958
